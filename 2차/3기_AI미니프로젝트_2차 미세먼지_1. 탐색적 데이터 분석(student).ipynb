# %% [markdown]
# **AIVLE School 미니프로젝트**
# ### **공공데이터를 활용한 <span style="color:darkgreen">미세먼지 농도</span> 예측**
# ---

# %% [markdown]
# #### **<span style="color:red">[미션 안내]</span>**
# * 개인 미션: 미세먼지 농도를 예측하는 머신러닝 모델을 만드세요. ([2-1]부터 [2-10], [3-1]부터 [3-2] 까지 미션 수행)
# * 조별 미션: 개인 미션 수행한 내용에 대해 토론하여 발표 준비를 해주세요.

# %% [markdown]
# #### **<span style="color:red">[주피터 노트북 파일 안내]</span>**
# 1. 탐색적 데이터 분석(solution).ipynb: 미션 수행 대상 아님. 제공된 solution을 참고하여 [2-1]부터의 미션 수행을 위한 탐색적 데이터 분석 진행</br>
# 2. 데이터 전처리.ipynb: [2-1]부터 [2-8] 까지 미션 수행 대상</br>
# 3. 모델링(머신러닝).ipynb: [3-1]부터 [3-2] 까지 미션 수행 대상. [4-1]~[4-4]는 선택 사항임</br>

# %% [markdown]
# #### **<span style="color:red">[데이터 설명]</span>**
#
# * air_2021.csv : 2021년 미세먼지 데이터
# * air_2022.csv : 2022년 미세먼지 데이터
# * weather_2021.csv : 2021년 날씨 데이터
# * weather_2022.csv : 2022년 날씨 데이터
# * 학습 데이터: 2021년의 미세먼지 농도 데이터, 테스트 데이터: 2022년의 미세먼지 농도 데이터

# %% [markdown]
# # [Step 1] 탐색적 데이터 분석

# %% [markdown]
# #### **<span style="color:blue">[1-1] 필요한 라이브러리 설치</span>**

# %%
# 필요한 라이브러리 설치 및 임포트
# %pip install pandas seaborn

import pandas as pd
import seaborn as sns
import matplotlib as plt
# Out:
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: seaborn in c:\users\user\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\user\anaconda3\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\user\anaconda3\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib>=2.2->seaborn) (22.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[1-2] 미세먼지 데이터 불러오기</span>**

# %% [markdown]
# * Pandas 라이브러리를 활용해서 'air_2021.csv'파일을 'air_21' 변수에, 'air_2022.csv'파일을 'air_22' 변수에 저장하고 그 데이터를 확인하세요.
# * 구분자(sep) : ','
# * encoder = 'utf-8'
# * index_col = 0

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# 'air_2021.csv'파일을 'air_21' 변수에, 'air_2022.csv'파일을 'air_22' 변수에 저장

air_21 = pd.read_csv("C:/Users/User/iCloudDrive/AIVLE/3월/1~2주차/air_2021.csv", sep=',', index_col = 0, encoding = 'utf-8' )
air_22 = pd.read_csv("C:/Users/User/iCloudDrive/AIVLE/3월/1~2주차/air_2022.csv", sep=',', index_col = 0, encoding = 'utf-8' )

# %%
# air_21 데이터의 head 확인

air_21.head()
# Out:
#        지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0  서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002  0.039  31.0
# 1  서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002  0.035  27.0
# 2  서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002  0.033  28.0
# 3  서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002  0.030  26.0
# 4  서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003  0.026  26.0
#
#    PM25                주소
# 0  18.0  서울 종로구 종로35가길 19
# 1  16.0  서울 종로구 종로35가길 19
# 2  18.0  서울 종로구 종로35가길 19
# 3  16.0  서울 종로구 종로35가길 19
# 4  16.0  서울 종로구 종로35가길 19

# %%
# air_21 데이터의 shape 확인

air_21.shape
# Out:
# (8760, 12)

# %%
# air_22 데이터의 head 확인

air_21.head()
# Out:
#        지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0  서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002  0.039  31.0
# 1  서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002  0.035  27.0
# 2  서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002  0.033  28.0
# 3  서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002  0.030  26.0
# 4  서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003  0.026  26.0
#
#    PM25                주소
# 0  18.0  서울 종로구 종로35가길 19
# 1  16.0  서울 종로구 종로35가길 19
# 2  18.0  서울 종로구 종로35가길 19
# 3  16.0  서울 종로구 종로35가길 19
# 4  16.0  서울 종로구 종로35가길 19

# %%
# air_22 데이터의 shape 확인

air_22.shape
# Out:
# (2160, 12)

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[1-3] 날씨 데이터 불러오기</span>**

# %% [markdown]
# * Pandas 라이브러리를 활용해서 'weather_2021.csv'파일을 'weather_21' 변수에, 'weather_2022.csv'파일을 'weather_22' 변수에 저장하고 그 데이터를 확인하세요.
# * 구분자(sep) : ','
# * encoder = 'cp949'

# %%
#'weather_2021.csv'파일을 'weather_21' 변수에, 'weather_2022.csv'파일을 'weather_22' 변수에 저장

weather_21 = pd.read_csv("C:/Users/User/iCloudDrive/AIVLE/3월/1~2주차/weather_2021.csv", sep = ',', encoding='cp949')
weather_22 = pd.read_csv("C:/Users/User/iCloudDrive/AIVLE/3월/1~2주차/weather_2022.csv", sep = ',', encoding='cp949')

# %%
# 미세먼지 데이터와 같이 날씨 데이터의 head, shape 등을 확인

weather_21.head()
# Out:
#     지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 0  108  서울  2021-01-01 01:00    -8.7       NaN      NaN        NaN      2.4
# 1  108  서울  2021-01-01 02:00    -9.1       NaN      NaN        NaN      1.6
# 2  108  서울  2021-01-01 03:00    -9.3       NaN      NaN        NaN      1.1
# 3  108  서울  2021-01-01 04:00    -9.3       NaN      NaN        NaN      0.3
# 4  108  서울  2021-01-01 05:00    -9.7       NaN      NaN        NaN      1.9
#
#    풍속 QC플래그  풍향(16방위)  ...  최저운고(100m )  시정(10m)  지면상태(지면상태코드)  현상번호(국내식)  \
# 0       NaN     270.0  ...          NaN     2000           NaN        NaN
# 1       NaN     270.0  ...          NaN     2000           NaN        NaN
# 2       NaN     250.0  ...          NaN     2000           NaN        NaN
# 3       NaN       0.0  ...          NaN     2000           NaN        NaN
# 4       NaN      20.0  ...          NaN     2000           NaN        NaN
#
#    지면온도(°C)  지면온도 QC플래그  5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  \
# 0      -6.9         NaN          -1.0           -0.8            0.3
# 1      -7.1         NaN          -1.1           -0.8            0.3
# 2      -7.3         NaN          -1.2           -0.9            0.3
# 3      -7.5         NaN          -1.3           -1.0            0.2
# 4      -7.6         NaN          -1.3           -1.0            0.2
#
#    30cm 지중온도(°C)
# 0            1.6
# 1            1.6
# 2            1.6
# 3            1.5
# 4            1.5
#
# [5 rows x 38 columns]

# %%
weather_21.shape
# Out:
# (8759, 38)

# %%
weather_22.head()
# Out:
#     지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 0  108  서울  2022-01-01 00:00    -8.5       NaN      NaN        NaN      1.9
# 1  108  서울  2022-01-01 01:00    -9.2       NaN      NaN        NaN      1.8
# 2  108  서울  2022-01-01 02:00    -9.5       NaN      NaN        NaN      1.2
# 3  108  서울  2022-01-01 03:00    -9.3       NaN      NaN        NaN      1.4
# 4  108  서울  2022-01-01 04:00    -9.6       NaN      NaN        NaN      1.7
#
#    풍속 QC플래그  풍향(16방위)  ...  최저운고(100m )  시정(10m)  지면상태(지면상태코드)  현상번호(국내식)  \
# 0       NaN       320  ...          NaN     2000           NaN        NaN
# 1       NaN       270  ...          NaN     2000           NaN        NaN
# 2       NaN       270  ...          NaN     2000           NaN        NaN
# 3       NaN       290  ...          NaN     2000           NaN        NaN
# 4       NaN       340  ...          NaN     2000           NaN        NaN
#
#    지면온도(°C)  지면온도 QC플래그  5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  \
# 0      -7.0         NaN          -1.0           -1.0           -0.2
# 1      -7.2         NaN          -1.1           -1.1           -0.2
# 2      -7.5         NaN          -1.3           -1.2           -0.2
# 3      -7.6         NaN          -1.4           -1.2           -0.2
# 4      -7.6         NaN          -1.4           -1.3           -0.3
#
#    30cm 지중온도(°C)
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
#
# [5 rows x 38 columns]

# %%
weather_22.shape
# Out:
# (2160, 38)

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[1-4] 데이터 변수 확인</span>**

# %%
# 각 데이터프레임의 info 확인
air_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8760 entries, 0 to 8759
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      8760 non-null   object
#  1   망       8760 non-null   object
#  2   측정소코드   8760 non-null   int64
#  3   측정소명    8760 non-null   object
#  4   측정일시    8760 non-null   int64
#  5   SO2     8648 non-null   float64
#  6   CO      8680 non-null   float64
#  7   O3      8663 non-null   float64
#  8   NO2     8680 non-null   float64
#  9   PM10    8655 non-null   float64
#  10  PM25    8663 non-null   float64
#  11  주소      8760 non-null   object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 889.7+ KB

# %%
air_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2160 entries, 0 to 2159
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      2160 non-null   object
#  1   망       2160 non-null   object
#  2   측정소코드   2160 non-null   int64
#  3   측정소명    2160 non-null   object
#  4   측정일시    2160 non-null   int64
#  5   SO2     2139 non-null   float64
#  6   CO      2139 non-null   float64
#  7   O3      2139 non-null   float64
#  8   NO2     2139 non-null   float64
#  9   PM10    2122 non-null   float64
#  10  PM25    2135 non-null   float64
#  11  주소      2160 non-null   object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 219.4+ KB

# %%
weather_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8759 entries, 0 to 8758
# Data columns (total 38 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지점             8759 non-null   int64
#  1   지점명            8759 non-null   object
#  2   일시             8759 non-null   object
#  3   기온(°C)         8759 non-null   float64
#  4   기온 QC플래그       0 non-null      float64
#  5   강수량(mm)        949 non-null    float64
#  6   강수량 QC플래그      1763 non-null   float64
#  7   풍속(m/s)        8757 non-null   float64
#  8   풍속 QC플래그       2 non-null      float64
#  9   풍향(16방위)       8757 non-null   float64
#  10  풍향 QC플래그       2 non-null      float64
#  11  습도(%)          8759 non-null   int64
#  12  습도 QC플래그       0 non-null      float64
#  13  증기압(hPa)       8759 non-null   float64
#  14  이슬점온도(°C)      8759 non-null   float64
#  15  현지기압(hPa)      8759 non-null   float64
#  16  현지기압 QC플래그     0 non-null      float64
#  17  해면기압(hPa)      8759 non-null   float64
#  18  해면기압 QC플래그     0 non-null      float64
#  19  일조(hr)         4791 non-null   float64
#  20  일조 QC플래그       3968 non-null   float64
#  21  일사(MJ/m2)      4791 non-null   float64
#  22  일사 QC플래그       3968 non-null   float64
#  23  적설(cm)         379 non-null    float64
#  24  3시간신적설(cm)     29 non-null     float64
#  25  전운량(10분위)      8757 non-null   float64
#  26  중하층운량(10분위)    8759 non-null   int64
#  27  운형(운형약어)       4947 non-null   object
#  28  최저운고(100m )    4547 non-null   float64
#  29  시정(10m)        8759 non-null   int64
#  30  지면상태(지면상태코드)   0 non-null      float64
#  31  현상번호(국내식)      2125 non-null   float64
#  32  지면온도(°C)       8754 non-null   float64
#  33  지면온도 QC플래그     24 non-null     float64
#  34  5cm 지중온도(°C)   8754 non-null   float64
#  35  10cm 지중온도(°C)  8754 non-null   float64
#  36  20cm 지중온도(°C)  8754 non-null   float64
#  37  30cm 지중온도(°C)  8754 non-null   float64
# dtypes: float64(31), int64(4), object(3)
# memory usage: 2.5+ MB

# %%
weather_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 38 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지점             2160 non-null   int64
#  1   지점명            2160 non-null   object
#  2   일시             2160 non-null   object
#  3   기온(°C)         2160 non-null   float64
#  4   기온 QC플래그       0 non-null      float64
#  5   강수량(mm)        81 non-null     float64
#  6   강수량 QC플래그      382 non-null    float64
#  7   풍속(m/s)        2160 non-null   float64
#  8   풍속 QC플래그       0 non-null      float64
#  9   풍향(16방위)       2160 non-null   int64
#  10  풍향 QC플래그       0 non-null      float64
#  11  습도(%)          2160 non-null   int64
#  12  습도 QC플래그       0 non-null      float64
#  13  증기압(hPa)       2160 non-null   float64
#  14  이슬점온도(°C)      2160 non-null   float64
#  15  현지기압(hPa)      2160 non-null   float64
#  16  현지기압 QC플래그     0 non-null      float64
#  17  해면기압(hPa)      2160 non-null   float64
#  18  해면기압 QC플래그     0 non-null      float64
#  19  일조(hr)         1071 non-null   float64
#  20  일조 QC플래그       1089 non-null   float64
#  21  일사(MJ/m2)      1071 non-null   float64
#  22  일사 QC플래그       1089 non-null   float64
#  23  적설(cm)         140 non-null    float64
#  24  3시간신적설(cm)     15 non-null     float64
#  25  전운량(10분위)      2160 non-null   int64
#  26  중하층운량(10분위)    2160 non-null   int64
#  27  운형(운형약어)       939 non-null    object
#  28  최저운고(100m )    743 non-null    float64
#  29  시정(10m)        2160 non-null   int64
#  30  지면상태(지면상태코드)   0 non-null      float64
#  31  현상번호(국내식)      418 non-null    float64
#  32  지면온도(°C)       2160 non-null   float64
#  33  지면온도 QC플래그     7 non-null      float64
#  34  5cm 지중온도(°C)   2160 non-null   float64
#  35  10cm 지중온도(°C)  2160 non-null   float64
#  36  20cm 지중온도(°C)  2160 non-null   float64
#  37  30cm 지중온도(°C)  2160 non-null   float64
# dtypes: float64(29), int64(6), object(3)
# memory usage: 641.4+ KB

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[1-5] 미세먼지 데이터 분석</span>**

# %% [markdown]
# * 데이터 전처리와 모델링을 위해 데이터 분석을 진행해보세요. 시각화 등을 통해 관측치들의 패턴 탐색, 잘못된 자료 탐색, 변수들간의 관계 파악을 할 수 있습니다.

# %%
# 시각화 한글폰트 설정 (아래 코드를 실행하세요)

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
# air_21,air_22 의 다양한 변수에 대하여 시각화
import seaborn as sns

sns.heatmap(air_21.corr(), square=True, annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
import matplotlib.pyplot as plt
plt.scatter('PM25', 'PM10', data=air_21)

# %%
plt.scatter('CO', 'PM10', data=air_21)

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.

# %%
# 시각화를 통해 알게된 사실을 정리해봅니다.
# 1. 
# 2.
# 3.

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[1-6] 날씨 데이터 분석</span>**

# %%
weather_21.corr()
# Out:
#                지점    기온(°C)  기온 QC플래그   강수량(mm)  강수량 QC플래그   풍속(m/s)  \
# 지점            NaN       NaN       NaN       NaN        NaN       NaN
# 기온(°C)        NaN  1.000000       NaN -0.009142        NaN -0.068998
# 기온 QC플래그      NaN       NaN       NaN       NaN        NaN       NaN
# 강수량(mm)       NaN -0.009142       NaN  1.000000        NaN  0.195771
# 강수량 QC플래그     NaN       NaN       NaN       NaN        NaN       NaN
# 풍속(m/s)       NaN -0.068998       NaN  0.195771        NaN  1.000000
# 풍속 QC플래그      NaN       NaN       NaN       NaN        NaN       NaN
# 풍향(16방위)      NaN -0.181061       NaN -0.031724        NaN  0.172669
# 풍향 QC플래그      NaN       NaN       NaN       NaN        NaN       NaN
# 습도(%)         NaN  0.145404       NaN  0.254056        NaN -0.285136
# 습도 QC플래그      NaN       NaN       NaN       NaN        NaN       NaN
# 증기압(hPa)      NaN  0.881615       NaN  0.067937        NaN -0.147224
# 이슬점온도(°C)     NaN  0.926402       NaN  0.075776        NaN -0.168898
# 현지기압(hPa)     NaN -0.680025       NaN -0.114330        NaN -0.046459
# 현지기압 QC플래그    NaN       NaN       NaN       NaN        NaN       NaN
# 해면기압(hPa)     NaN -0.707822       NaN -0.112065        NaN -0.041041
# 해면기압 QC플래그    NaN       NaN       NaN       NaN        NaN       NaN
# 일조(hr)        NaN -0.030577       NaN -0.047097        NaN  0.175146
# 일조 QC플래그      NaN       NaN       NaN       NaN        NaN       NaN
# 일사(MJ/m2)     NaN  0.259726       NaN -0.151331        NaN  0.188221
# 일사 QC플래그      NaN       NaN       NaN       NaN        NaN       NaN
# 적설(cm)        NaN  0.273284       NaN  0.300225        NaN -0.095575
# 3시간신적설(cm)    NaN  0.177476       NaN  0.723086        NaN  0.032427
# 전운량(10분위)     NaN  0.307568       NaN  0.101299        NaN -0.026692
# 중하층운량(10분위)   NaN  0.153382       NaN  0.181165        NaN  0.036578
# 최저운고(100m )   NaN  0.080681       NaN -0.178925        NaN -0.104431
# 시정(10m)       NaN  0.068418       NaN -0.374583        NaN  0.106293
# 지면상태(지면상태코드)  NaN       NaN       NaN       NaN        NaN       NaN
# 현상번호(국내식)     NaN -0.014230       NaN  0.051938        NaN  0.064581
# 지면온도(°C)      NaN  0.946652       NaN -0.021841        NaN  0.015133
# 지면온도 QC플래그    NaN -0.279912       NaN       NaN        NaN -0.523815
# 5cm 지중온도(°C)  NaN  0.951015       NaN -0.001349        NaN -0.067677
# 10cm 지중온도(°C) NaN  0.938467       NaN  0.023574        NaN -0.082121
# 20cm 지중온도(°C) NaN  0.917756       NaN  0.021270        NaN -0.102176
# 30cm 지중온도(°C) NaN  0.901939       NaN  0.018687        NaN -0.111688
#
#                풍속 QC플래그  풍향(16방위)  풍향 QC플래그     습도(%)  ...  최저운고(100m )  \
# 지점                  NaN       NaN       NaN       NaN  ...          NaN
# 기온(°C)              NaN -0.181061       NaN  0.145404  ...     0.080681
# 기온 QC플래그            NaN       NaN       NaN       NaN  ...          NaN
# 강수량(mm)             NaN -0.031724       NaN  0.254056  ...    -0.178925
# 강수량 QC플래그           NaN       NaN       NaN       NaN  ...          NaN
# 풍속(m/s)             NaN  0.172669       NaN -0.285136  ...    -0.104431
# 풍속 QC플래그            NaN       NaN       NaN       NaN  ...          NaN
# 풍향(16방위)            NaN  1.000000       NaN -0.200744  ...    -0.076933
# 풍향 QC플래그            NaN       NaN       NaN       NaN  ...          NaN
# 습도(%)               NaN -0.200744       NaN  1.000000  ...    -0.336348
# 습도 QC플래그            NaN       NaN       NaN       NaN  ...          NaN
# 증기압(hPa)            NaN -0.188806       NaN  0.450867  ...    -0.067908
# 이슬점온도(°C)           NaN -0.231501       NaN  0.501853  ...    -0.053618
# 현지기압(hPa)           NaN  0.043715       NaN -0.359807  ...     0.196248
# 현지기압 QC플래그          NaN       NaN       NaN       NaN  ...          NaN
# 해면기압(hPa)           NaN  0.051917       NaN -0.354960  ...     0.185978
# 해면기압 QC플래그          NaN       NaN       NaN       NaN  ...          NaN
# 일조(hr)              NaN  0.116463       NaN -0.561533  ...     0.036772
# 일조 QC플래그            NaN       NaN       NaN       NaN  ...          NaN
# 일사(MJ/m2)           NaN  0.075342       NaN -0.505902  ...     0.009990
# 일사 QC플래그            NaN       NaN       NaN       NaN  ...          NaN
# 적설(cm)              NaN -0.103654       NaN  0.370726  ...    -0.283868
# 3시간신적설(cm)          NaN  0.094528       NaN  0.521972  ...    -0.259206
# 전운량(10분위)           NaN -0.176713       NaN  0.362256  ...    -0.061855
# 중하층운량(10분위)         NaN -0.094902       NaN  0.379977  ...    -0.088167
# 최저운고(100m )         NaN -0.076933       NaN -0.336348  ...     1.000000
# 시정(10m)             NaN  0.025421       NaN -0.501758  ...     0.281511
# 지면상태(지면상태코드)        NaN       NaN       NaN       NaN  ...          NaN
# 현상번호(국내식)           NaN  0.009358       NaN  0.032839  ...    -0.023016
# 지면온도(°C)            NaN -0.138250       NaN  0.055100  ...     0.016381
# 지면온도 QC플래그          NaN  0.839372       NaN  0.967964  ...    -0.683349
# 5cm 지중온도(°C)        NaN -0.146987       NaN  0.220990  ...     0.075178
# 10cm 지중온도(°C)       NaN -0.153432       NaN  0.248125  ...     0.079823
# 20cm 지중온도(°C)       NaN -0.165741       NaN  0.283483  ...     0.081039
# 30cm 지중온도(°C)       NaN -0.175479       NaN  0.303598  ...     0.071479
#
#                 시정(10m)  지면상태(지면상태코드)  현상번호(국내식)  지면온도(°C)  지면온도 QC플래그  \
# 지점                  NaN           NaN        NaN       NaN         NaN
# 기온(°C)         0.068418           NaN  -0.014230  0.946652   -0.279912
# 기온 QC플래그            NaN           NaN        NaN       NaN         NaN
# 강수량(mm)       -0.374583           NaN   0.051938 -0.021841         NaN
# 강수량 QC플래그           NaN           NaN        NaN       NaN         NaN
# 풍속(m/s)        0.106293           NaN   0.064581  0.015133   -0.523815
# 풍속 QC플래그            NaN           NaN        NaN       NaN         NaN
# 풍향(16방위)       0.025421           NaN   0.009358 -0.138250    0.839372
# 풍향 QC플래그            NaN           NaN        NaN       NaN         NaN
# 습도(%)         -0.501758           NaN   0.032839  0.055100    0.967964
# 습도 QC플래그            NaN           NaN        NaN       NaN         NaN
# 증기압(hPa)      -0.038048           NaN  -0.007656  0.830661    0.131271
# 이슬점온도(°C)     -0.108015           NaN  -0.001753  0.846042    0.194510
# 현지기압(hPa)      0.140369           NaN  -0.043041 -0.646061    0.038601
# 현지기압 QC플래그          NaN           NaN        NaN       NaN         NaN
# 해면기압(hPa)      0.132208           NaN  -0.041420 -0.672032    0.046162
# 해면기압 QC플래그          NaN           NaN        NaN       NaN         NaN
# 일조(hr)         0.280292           NaN  -0.017369  0.139113         NaN
# 일조 QC플래그            NaN           NaN        NaN       NaN         NaN
# 일사(MJ/m2)      0.267643           NaN  -0.027135  0.500464         NaN
# 일사 QC플래그            NaN           NaN        NaN       NaN         NaN
# 적설(cm)        -0.423011           NaN  -0.081491  0.279590         NaN
# 3시간신적설(cm)    -0.422810           NaN   0.284944  0.211076         NaN
# 전운량(10분위)     -0.240816           NaN   0.022777  0.248266    0.217909
# 중하층운량(10분위)   -0.271131           NaN   0.032836  0.115353   -0.180548
# 최저운고(100m )    0.281511           NaN  -0.023016  0.016381   -0.683349
# 시정(10m)        1.000000           NaN  -0.037700  0.111068   -0.880423
# 지면상태(지면상태코드)        NaN           NaN        NaN       NaN         NaN
# 현상번호(국내식)     -0.037700           NaN   1.000000 -0.010353         NaN
# 지면온도(°C)       0.111068           NaN  -0.010353  1.000000         NaN
# 지면온도 QC플래그    -0.880423           NaN        NaN       NaN    1.000000
# 5cm 지중온도(°C)   0.096837           NaN  -0.005950  0.917016         NaN
# 10cm 지중온도(°C)  0.093570           NaN  -0.005502  0.898364         NaN
# 20cm 지중온도(°C)  0.090969           NaN  -0.005595  0.875312         NaN
# 30cm 지중온도(°C)  0.093621           NaN  -0.006615  0.865629         NaN
#
#                5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# 지점                      NaN            NaN            NaN            NaN
# 기온(°C)             0.951015       0.938467       0.917756       0.901939
# 기온 QC플래그                NaN            NaN            NaN            NaN
# 강수량(mm)           -0.001349       0.023574       0.021270       0.018687
# 강수량 QC플래그               NaN            NaN            NaN            NaN
# 풍속(m/s)           -0.067677      -0.082121      -0.102176      -0.111688
# 풍속 QC플래그                NaN            NaN            NaN            NaN
# 풍향(16방위)          -0.146987      -0.153432      -0.165741      -0.175479
# 풍향 QC플래그                NaN            NaN            NaN            NaN
# 습도(%)              0.220990       0.248125       0.283483       0.303598
# 습도 QC플래그                NaN            NaN            NaN            NaN
# 증기압(hPa)           0.912350       0.915020       0.915212       0.913743
# 이슬점온도(°C)          0.917517       0.917805       0.914310       0.908773
# 현지기압(hPa)         -0.703667      -0.699846      -0.692715      -0.682998
# 현지기압 QC플래그              NaN            NaN            NaN            NaN
# 해면기압(hPa)         -0.727896      -0.723577      -0.715649      -0.705462
# 해면기압 QC플래그              NaN            NaN            NaN            NaN
# 일조(hr)            -0.112766      -0.137599      -0.159988      -0.162086
# 일조 QC플래그                NaN            NaN            NaN            NaN
# 일사(MJ/m2)          0.150922       0.110311       0.072757       0.067647
# 일사 QC플래그                NaN            NaN            NaN            NaN
# 적설(cm)             0.250546       0.239310       0.211504       0.175734
# 3시간신적설(cm)        -0.001824      -0.021254      -0.038410      -0.043824
# 전운량(10분위)          0.267489       0.265319       0.260374       0.256975
# 중하층운량(10분위)        0.133385       0.133355       0.132747       0.133840
# 최저운고(100m )        0.075178       0.079823       0.081039       0.071479
# 시정(10m)            0.096837       0.093570       0.090969       0.093621
# 지면상태(지면상태코드)            NaN            NaN            NaN            NaN
# 현상번호(국내식)         -0.005950      -0.005502      -0.005595      -0.006615
# 지면온도(°C)           0.917016       0.898364       0.875312       0.865629
# 지면온도 QC플래그              NaN            NaN            NaN            NaN
# 5cm 지중온도(°C)       1.000000       0.998379       0.991311       0.982874
# 10cm 지중온도(°C)      0.998379       1.000000       0.996931       0.990547
# 20cm 지중온도(°C)      0.991311       0.996931       1.000000       0.997712
# 30cm 지중온도(°C)      0.982874       0.990547       0.997712       1.000000
#
# [35 rows x 35 columns]

# %%
# weather_21,weather_22 의 다양한 변수에 대하여 시각화

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.

# %%
# 시각화를 통해 알게된 사실을 정리해봅니다.
# 1. 
# 2.
# 3.
