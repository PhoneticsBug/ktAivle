# %%
# 필요한 라이브러리 설치 및 임포트
# !pip install pandas

import pandas as pd
import datetime
# Out:
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ---

# %% [markdown]
# # [Step 2] 데이터 전처리

# %% [markdown]
# #### **<span style="color:blue">[2-0] air_21, air_22, weather_21, weather_22 데이터 로딩</span>**

# %%
# 데이터 로딩
air_21 = pd.read_csv("C:/Users/User/iCloudDrive/AIVLE/3월/1~2주차/air_2021.csv", sep=',', index_col = 0, encoding = 'utf-8' )
air_22 = pd.read_csv("C:/Users/User/iCloudDrive/AIVLE/3월/1~2주차/air_2022.csv", sep=',', index_col = 0, encoding = 'utf-8' )
weather_21 = pd.read_csv("C:/Users/User/iCloudDrive/AIVLE/3월/1~2주차/weather_2021.csv", sep = ',', encoding='cp949')
weather_22 = pd.read_csv("C:/Users/User/iCloudDrive/AIVLE/3월/1~2주차/weather_2022.csv", sep = ',', encoding='cp949')

# %% [markdown]
# #### **<span style="color:blue">[2-1] air_21, air_22 의 '측정일시'를 활용하여 'time' 변수 생성</span>**

# %% [markdown]
# * air_21, air_22 의 '측정일시'를 활용하여 'time'변수 생성
# * time 변수를 to_datetime으로 데이터 타입 변경
# * 참고: 미세먼지 데이터는 1시-24시, 날씨 데이터는 0시-23시로 구성되어 있습니다. [2-5]에서 미세먼지와 날씨 데이터를 time 기준으로 합치려면 날씨 기준이 동일해야 합니다. 미세먼지 데이터에서 time 변수 생성 시 이를 미리 고려(예:측정일시 값 -1)하세요.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
air_21['time'] = pd.to_datetime(air_21['측정일시']-1, format='%Y%m%d%H')
air_22['time'] = pd.to_datetime(air_22['측정일시']-1, format='%Y%m%d%H')

# %%
air_21
# Out:
#           지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0     서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002  0.039  31.0
# 1     서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002  0.035  27.0
# 2     서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002  0.033  28.0
# 3     서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002  0.030  26.0
# 4     서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003  0.026  26.0
# ...      ...   ...     ...  ...         ...    ...  ...    ...    ...   ...
# 8755  서울 종로구  도시대기  111123  종로구  2021093020  0.003  0.7  0.020  0.036  35.0
# 8756  서울 종로구  도시대기  111123  종로구  2021093021  0.003  0.6  0.016  0.035  34.0
# 8757  서울 종로구  도시대기  111123  종로구  2021093022  0.003  0.6  0.012  0.036  30.0
# 8758  서울 종로구  도시대기  111123  종로구  2021093023  0.003  0.6  0.004  0.042  33.0
# 8759  서울 종로구  도시대기  111123  종로구  2021093024  0.003  0.6  0.003  0.042  29.0
#
#       PM25                주소                time
# 0     18.0  서울 종로구 종로35가길 19 2021-10-01 00:00:00
# 1     16.0  서울 종로구 종로35가길 19 2021-10-01 01:00:00
# 2     18.0  서울 종로구 종로35가길 19 2021-10-01 02:00:00
# 3     16.0  서울 종로구 종로35가길 19 2021-10-01 03:00:00
# 4     16.0  서울 종로구 종로35가길 19 2021-10-01 04:00:00
# ...    ...               ...                 ...
# 8755  24.0  서울 종로구 종로35가길 19 2021-09-30 19:00:00
# 8756  21.0  서울 종로구 종로35가길 19 2021-09-30 20:00:00
# 8757  19.0  서울 종로구 종로35가길 19 2021-09-30 21:00:00
# 8758  19.0  서울 종로구 종로35가길 19 2021-09-30 22:00:00
# 8759  17.0  서울 종로구 종로35가길 19 2021-09-30 23:00:00
#
# [8760 rows x 13 columns]

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-2] weather_21, weather_22 의 '일시'를 활용하여 'time' 변수 생성</span>**

# %% [markdown]
# * weather_21, weather_22 의 '일시'를 활용하여 'time'변수 생성
# * time 변수를 to_datetime으로 데이터 타입 변경

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
weather_21['time'] = pd.to_datetime(weather_21['일시'])
weather_22['time'] = pd.to_datetime(weather_22['일시'])

# %%
weather_21['time']
# Out:
# 0      2021-01-01 01:00:00
# 1      2021-01-01 02:00:00
# 2      2021-01-01 03:00:00
# 3      2021-01-01 04:00:00
# 4      2021-01-01 05:00:00
#                ...
# 8754   2021-12-31 19:00:00
# 8755   2021-12-31 20:00:00
# 8756   2021-12-31 21:00:00
# 8757   2021-12-31 22:00:00
# 8758   2021-12-31 23:00:00
# Name: time, Length: 8759, dtype: datetime64[ns]

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-3] 'time' 기준으로 데이터 합치기</span>**

# %% [markdown]
# * 미세먼지 데이터와 날씨 데이터를 'time' 기준으로 합쳐보세요.
# * df_21에는 'time' 기준으로 21년도 미세먼지, 날씨 데이터를 합쳐보세요.
# * df_22에는 'time' 기준으로 22년도 미세먼지, 날씨 데이터를 합쳐보세요.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.
df_21 = pd.merge(air_21, weather_21, how='inner', on='time')
df_22 = pd.merge(air_22, weather_22, how='inner', on='time')

# %%
df_21
# Out:
#           지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0     서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002  0.039  31.0
# 1     서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002  0.035  27.0
# 2     서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002  0.033  28.0
# 3     서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002  0.030  26.0
# 4     서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003  0.026  26.0
# ...      ...   ...     ...  ...         ...    ...  ...    ...    ...   ...
# 8754  서울 종로구  도시대기  111123  종로구  2021093020  0.003  0.7  0.020  0.036  35.0
# 8755  서울 종로구  도시대기  111123  종로구  2021093021  0.003  0.6  0.016  0.035  34.0
# 8756  서울 종로구  도시대기  111123  종로구  2021093022  0.003  0.6  0.012  0.036  30.0
# 8757  서울 종로구  도시대기  111123  종로구  2021093023  0.003  0.6  0.004  0.042  33.0
# 8758  서울 종로구  도시대기  111123  종로구  2021093024  0.003  0.6  0.003  0.042  29.0
#
#       ...  최저운고(100m ) 시정(10m) 지면상태(지면상태코드)  현상번호(국내식) 지면온도(°C) 지면온도 QC플래그  \
# 0     ...          NaN    2000          NaN        NaN     17.8        NaN
# 1     ...          NaN    2000          NaN        NaN     17.4        NaN
# 2     ...          NaN    2000          NaN        NaN     17.2        NaN
# 3     ...          NaN    2000          NaN        NaN     17.0        NaN
# 4     ...          NaN    2000          NaN        NaN     16.5        NaN
# ...   ...          ...     ...          ...        ...      ...        ...
# 8754  ...          NaN    2000          NaN        NaN     20.6        NaN
# 8755  ...          NaN    2000          NaN        NaN     19.9        NaN
# 8756  ...          NaN    2000          NaN        NaN     19.2        NaN
# 8757  ...          NaN    2000          NaN        NaN     18.6        NaN
# 8758  ...          NaN    2000          NaN        NaN     18.1        NaN
#
#       5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# 0             22.3           22.3           22.7           22.9
# 1             22.1           22.0           22.5           22.9
# 2             21.8           21.8           22.4           22.8
# 3             21.6           21.6           22.2           22.8
# 4             21.3           21.4           22.0           22.7
# ...            ...            ...            ...            ...
# 8754          24.2           23.7           23.0           22.6
# 8755          23.7           23.4           23.1           22.8
# 8756          23.3           23.1           23.0           22.9
# 8757          23.0           22.8           22.9           22.9
# 8758          22.6           22.5           22.8           22.9
#
# [8759 rows x 51 columns]

# %%
df_22
# Out:
#           지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0     서울 종로구  도시대기  111123  종로구  2022010101  0.003  0.4  0.026  0.016  23.0
# 1     서울 종로구  도시대기  111123  종로구  2022010102  0.003  0.4  0.022  0.020  20.0
# 2     서울 종로구  도시대기  111123  종로구  2022010103  0.003  0.5  0.014  0.028  20.0
# 3     서울 종로구  도시대기  111123  종로구  2022010104  0.003  0.5  0.016  0.027  19.0
# 4     서울 종로구  도시대기  111123  종로구  2022010105  0.003  0.5  0.005  0.040  24.0
# ...      ...   ...     ...  ...         ...    ...  ...    ...    ...   ...
# 2155  서울 종로구  도시대기  111123  종로구  2022033120  0.002  0.4  0.036  0.017  11.0
# 2156  서울 종로구  도시대기  111123  종로구  2022033121  0.002  0.4  0.032  0.018  10.0
# 2157  서울 종로구  도시대기  111123  종로구  2022033122  0.003  0.3  0.038  0.013  11.0
# 2158  서울 종로구  도시대기  111123  종로구  2022033123  0.003  0.3  0.036  0.015  11.0
# 2159  서울 종로구  도시대기  111123  종로구  2022033124  0.002  0.4  0.033  0.017   9.0
#
#       ...  최저운고(100m ) 시정(10m) 지면상태(지면상태코드)  현상번호(국내식) 지면온도(°C) 지면온도 QC플래그  \
# 0     ...          NaN    2000          NaN        NaN     -7.0        NaN
# 1     ...          NaN    2000          NaN        NaN     -7.2        NaN
# 2     ...          NaN    2000          NaN        NaN     -7.5        NaN
# 3     ...          NaN    2000          NaN        NaN     -7.6        NaN
# 4     ...          NaN    2000          NaN        NaN     -7.6        NaN
# ...   ...          ...     ...          ...        ...      ...        ...
# 2155  ...          9.0    2000          NaN        NaN     10.0        NaN
# 2156  ...          NaN    2000          NaN        NaN      8.9        NaN
# 2157  ...         10.0    2000          NaN        NaN      7.8        NaN
# 2158  ...         10.0    2000          NaN        NaN      7.3        NaN
# 2159  ...         10.0    2000          NaN        NaN      6.7        NaN
#
#       5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# 0             -1.0           -1.0           -0.2            1.0
# 1             -1.1           -1.1           -0.2            1.0
# 2             -1.3           -1.2           -0.2            1.0
# 3             -1.4           -1.2           -0.2            1.0
# 4             -1.4           -1.3           -0.3            1.0
# ...            ...            ...            ...            ...
# 2155          12.6           11.8           11.0           10.2
# 2156          12.2           11.6           11.0           10.3
# 2157          11.8           11.4           11.0           10.4
# 2158          11.4           11.1           10.9           10.5
# 2159          11.0           10.8           10.8           10.5
#
# [2160 rows x 51 columns]

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-4] 사용하지 않을 변수 제거</span>**

# %% [markdown]
# * 머신러닝에 사용하지 않을 변수들을 제거해줍니다.
# * df_21, df_22에 사용할 변수들만 넣어보세요.

# %%
df_21.isnull().sum()
# Out:
# 지역                  0
# 망                   0
# 측정소코드               0
# 측정소명                0
# 측정일시                0
# SO2               112
# CO                 80
# O3                 97
# NO2                80
# PM10              105
# PM25               97
# 주소                  0
# time                0
# 지점                  0
# 지점명                 0
# 일시                  0
# 기온(°C)              0
# 기온 QC플래그         8759
# 강수량(mm)          7810
# 강수량 QC플래그        6996
# 풍속(m/s)             2
# 풍속 QC플래그         8757
# 풍향(16방위)            2
# 풍향 QC플래그         8757
# 습도(%)               0
# 습도 QC플래그         8759
# 증기압(hPa)            0
# 이슬점온도(°C)           0
# 현지기압(hPa)           0
# 현지기압 QC플래그       8759
# 해면기압(hPa)           0
# 해면기압 QC플래그       8759
# 일조(hr)           3968
# 일조 QC플래그         4791
# 일사(MJ/m2)        3968
# 일사 QC플래그         4791
# 적설(cm)           8380
# 3시간신적설(cm)       8730
# 전운량(10분위)           2
# 중하층운량(10분위)         0
# 운형(운형약어)         3812
# 최저운고(100m )      4212
# 시정(10m)             0
# 지면상태(지면상태코드)     8759
# 현상번호(국내식)        6634
# 지면온도(°C)            5
# 지면온도 QC플래그       8735
# 5cm 지중온도(°C)        5
# 10cm 지중온도(°C)       5
# 20cm 지중온도(°C)       5
# 30cm 지중온도(°C)       5
# dtype: int64

# %%
df_21.columns
# Out:
# Index(['지역', '망', '측정소코드', '측정소명', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10',
#        'PM25', '주소', 'time', '지점', '지점명', '일시', '기온(°C)', '기온 QC플래그',
#        '강수량(mm)', '강수량 QC플래그', '풍속(m/s)', '풍속 QC플래그', '풍향(16방위)', '풍향 QC플래그',
#        '습도(%)', '습도 QC플래그', '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)', '현지기압 QC플래그',
#        '해면기압(hPa)', '해면기압 QC플래그', '일조(hr)', '일조 QC플래그', '일사(MJ/m2)',
#        '일사 QC플래그', '적설(cm)', '3시간신적설(cm)', '전운량(10분위)', '중하층운량(10분위)',
#        '운형(운형약어)', '최저운고(100m )', '시정(10m)', '지면상태(지면상태코드)', '현상번호(국내식)',
#        '지면온도(°C)', '지면온도 QC플래그', '5cm 지중온도(°C)', '10cm 지중온도(°C)',
#        '20cm 지중온도(°C)', '30cm 지중온도(°C)'],
#       dtype='object')

# %%
# df_21, df_22에 사용할 변수들만 할당
df_21.drop(['기온 QC플래그', '강수량 QC플래그', '풍속 QC플래그', '풍향 QC플래그', 
                             '습도 QC플래그', '현지기압 QC플래그', '해면기압 QC플래그', '지점', '지점명', 
                 '지면상태(지면상태코드)', '지면온도 QC플래그', '현상번호(국내식)', '운형(운형약어)', '최저운고(100m )' , 
            '일조(hr)', '일조 QC플래그', '일사(MJ/m2)' , '일사 QC플래그'    ], axis=1, inplace=True)
df_22.drop(['기온 QC플래그', '강수량 QC플래그', '풍속 QC플래그', '풍향 QC플래그', 
                             '습도 QC플래그', '현지기압 QC플래그', '해면기압 QC플래그', '지점', '지점명', 
                 '지면상태(지면상태코드)', '지면온도 QC플래그', '현상번호(국내식)', '운형(운형약어)', '최저운고(100m )' , 
            '일조(hr)', '일조 QC플래그', '일사(MJ/m2)' , '일사 QC플래그'    ], axis=1, inplace=True)
df_21.columns
# Out:
# Index(['지역', '망', '측정소코드', '측정소명', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10',
#        'PM25', '주소', 'time', '일시', '기온(°C)', '강수량(mm)', '풍속(m/s)', '풍향(16방위)',
#        '습도(%)', '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)', '해면기압(hPa)', '적설(cm)',
#        '3시간신적설(cm)', '전운량(10분위)', '중하층운량(10분위)', '시정(10m)', '지면온도(°C)',
#        '5cm 지중온도(°C)', '10cm 지중온도(°C)', '20cm 지중온도(°C)', '30cm 지중온도(°C)'],
#       dtype='object')

# %%
# time 변수를 index로 세팅
df_21.set_index(keys='time')
df_22.set_index(keys='time')
# Out:
#                          지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3  \
# time
# 2022-01-01 00:00:00  서울 종로구  도시대기  111123  종로구  2022010101  0.003  0.4  0.026
# 2022-01-01 01:00:00  서울 종로구  도시대기  111123  종로구  2022010102  0.003  0.4  0.022
# 2022-01-01 02:00:00  서울 종로구  도시대기  111123  종로구  2022010103  0.003  0.5  0.014
# 2022-01-01 03:00:00  서울 종로구  도시대기  111123  종로구  2022010104  0.003  0.5  0.016
# 2022-01-01 04:00:00  서울 종로구  도시대기  111123  종로구  2022010105  0.003  0.5  0.005
# ...                     ...   ...     ...  ...         ...    ...  ...    ...
# 2022-03-31 19:00:00  서울 종로구  도시대기  111123  종로구  2022033120  0.002  0.4  0.036
# 2022-03-31 20:00:00  서울 종로구  도시대기  111123  종로구  2022033121  0.002  0.4  0.032
# 2022-03-31 21:00:00  서울 종로구  도시대기  111123  종로구  2022033122  0.003  0.3  0.038
# 2022-03-31 22:00:00  서울 종로구  도시대기  111123  종로구  2022033123  0.003  0.3  0.036
# 2022-03-31 23:00:00  서울 종로구  도시대기  111123  종로구  2022033124  0.002  0.4  0.033
#
#                        NO2  PM10  ...  적설(cm) 3시간신적설(cm) 전운량(10분위)  \
# time                              ...
# 2022-01-01 00:00:00  0.016  23.0  ...     NaN        NaN         0
# 2022-01-01 01:00:00  0.020  20.0  ...     NaN        NaN         0
# 2022-01-01 02:00:00  0.028  20.0  ...     NaN        NaN         0
# 2022-01-01 03:00:00  0.027  19.0  ...     NaN        NaN         0
# 2022-01-01 04:00:00  0.040  24.0  ...     NaN        NaN         0
# ...                    ...   ...  ...     ...        ...       ...
# 2022-03-31 19:00:00  0.017  11.0  ...     NaN        NaN         6
# 2022-03-31 20:00:00  0.018  10.0  ...     NaN        NaN         6
# 2022-03-31 21:00:00  0.013  11.0  ...     NaN        NaN         1
# 2022-03-31 22:00:00  0.015  11.0  ...     NaN        NaN         3
# 2022-03-31 23:00:00  0.017   9.0  ...     NaN        NaN         1
#
#                      중하층운량(10분위)  시정(10m)  지면온도(°C)  5cm 지중온도(°C)  \
# time
# 2022-01-01 00:00:00            0     2000      -7.0          -1.0
# 2022-01-01 01:00:00            0     2000      -7.2          -1.1
# 2022-01-01 02:00:00            0     2000      -7.5          -1.3
# 2022-01-01 03:00:00            0     2000      -7.6          -1.4
# 2022-01-01 04:00:00            0     2000      -7.6          -1.4
# ...                          ...      ...       ...           ...
# 2022-03-31 19:00:00            1     2000      10.0          12.6
# 2022-03-31 20:00:00            0     2000       8.9          12.2
# 2022-03-31 21:00:00            1     2000       7.8          11.8
# 2022-03-31 22:00:00            3     2000       7.3          11.4
# 2022-03-31 23:00:00            1     2000       6.7          11.0
#
#                      10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# time
# 2022-01-01 00:00:00           -1.0           -0.2            1.0
# 2022-01-01 01:00:00           -1.1           -0.2            1.0
# 2022-01-01 02:00:00           -1.2           -0.2            1.0
# 2022-01-01 03:00:00           -1.2           -0.2            1.0
# 2022-01-01 04:00:00           -1.3           -0.3            1.0
# ...                            ...            ...            ...
# 2022-03-31 19:00:00           11.8           11.0           10.2
# 2022-03-31 20:00:00           11.6           11.0           10.3
# 2022-03-31 21:00:00           11.4           11.0           10.4
# 2022-03-31 22:00:00           11.1           10.9           10.5
# 2022-03-31 23:00:00           10.8           10.8           10.5
#
# [2160 rows x 32 columns]

# %%
df_21
# Out:
#           지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0     서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002  0.039  31.0
# 1     서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002  0.035  27.0
# 2     서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002  0.033  28.0
# 3     서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002  0.030  26.0
# 4     서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003  0.026  26.0
# ...      ...   ...     ...  ...         ...    ...  ...    ...    ...   ...
# 8754  서울 종로구  도시대기  111123  종로구  2021093020  0.003  0.7  0.020  0.036  35.0
# 8755  서울 종로구  도시대기  111123  종로구  2021093021  0.003  0.6  0.016  0.035  34.0
# 8756  서울 종로구  도시대기  111123  종로구  2021093022  0.003  0.6  0.012  0.036  30.0
# 8757  서울 종로구  도시대기  111123  종로구  2021093023  0.003  0.6  0.004  0.042  33.0
# 8758  서울 종로구  도시대기  111123  종로구  2021093024  0.003  0.6  0.003  0.042  29.0
#
#       ...  적설(cm) 3시간신적설(cm) 전운량(10분위) 중하층운량(10분위)  시정(10m)  지면온도(°C)  \
# 0     ...     NaN        NaN       0.0           0     2000      17.8
# 1     ...     NaN        NaN       0.0           0     2000      17.4
# 2     ...     NaN        NaN       0.0           0     2000      17.2
# 3     ...     NaN        NaN       0.0           0     2000      17.0
# 4     ...     NaN        NaN       0.0           0     2000      16.5
# ...   ...     ...        ...       ...         ...      ...       ...
# 8754  ...     NaN        NaN       0.0           0     2000      20.6
# 8755  ...     NaN        NaN       0.0           0     2000      19.9
# 8756  ...     NaN        NaN       0.0           0     2000      19.2
# 8757  ...     NaN        NaN       0.0           0     2000      18.6
# 8758  ...     NaN        NaN       0.0           0     2000      18.1
#
#       5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# 0             22.3           22.3           22.7           22.9
# 1             22.1           22.0           22.5           22.9
# 2             21.8           21.8           22.4           22.8
# 3             21.6           21.6           22.2           22.8
# 4             21.3           21.4           22.0           22.7
# ...            ...            ...            ...            ...
# 8754          24.2           23.7           23.0           22.6
# 8755          23.7           23.4           23.1           22.8
# 8756          23.3           23.1           23.0           22.9
# 8757          23.0           22.8           22.9           22.9
# 8758          22.6           22.5           22.8           22.9
#
# [8759 rows x 33 columns]

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-5] 변수들의 결측치 처리</span>**

# %%
# df_21, df_22의 결측치 확인
df_21.isnull().sum()
# Out:
# 지역                  0
# 망                   0
# 측정소코드               0
# 측정소명                0
# 측정일시                0
# SO2               112
# CO                 80
# O3                 97
# NO2                80
# PM10              105
# PM25               97
# 주소                  0
# time                0
# 일시                  0
# 기온(°C)              0
# 강수량(mm)          7810
# 풍속(m/s)             2
# 풍향(16방위)            2
# 습도(%)               0
# 증기압(hPa)            0
# 이슬점온도(°C)           0
# 현지기압(hPa)           0
# 해면기압(hPa)           0
# 적설(cm)           8380
# 3시간신적설(cm)       8730
# 전운량(10분위)           2
# 중하층운량(10분위)         0
# 시정(10m)             0
# 지면온도(°C)            5
# 5cm 지중온도(°C)        5
# 10cm 지중온도(°C)       5
# 20cm 지중온도(°C)       5
# 30cm 지중온도(°C)       5
# dtype: int64

# %%
# df_21, df_22의 변수 중 '강수량(mm)'의 결측치를 처리
df_21['강수량(mm)'].fillna(0, inplace=True)
df_22['강수량(mm)'].fillna(0, inplace=True)
df_21['적설(cm)'].fillna(0, inplace=True)
df_22['적설(cm)'].fillna(0, inplace=True)
df_21['3시간신적설(cm)'].fillna(0, inplace=True)
df_22['3시간신적설(cm)'].fillna(0, inplace=True)
df_21
# Out:
#           지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0     서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002  0.039  31.0
# 1     서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002  0.035  27.0
# 2     서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002  0.033  28.0
# 3     서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002  0.030  26.0
# 4     서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003  0.026  26.0
# ...      ...   ...     ...  ...         ...    ...  ...    ...    ...   ...
# 8754  서울 종로구  도시대기  111123  종로구  2021093020  0.003  0.7  0.020  0.036  35.0
# 8755  서울 종로구  도시대기  111123  종로구  2021093021  0.003  0.6  0.016  0.035  34.0
# 8756  서울 종로구  도시대기  111123  종로구  2021093022  0.003  0.6  0.012  0.036  30.0
# 8757  서울 종로구  도시대기  111123  종로구  2021093023  0.003  0.6  0.004  0.042  33.0
# 8758  서울 종로구  도시대기  111123  종로구  2021093024  0.003  0.6  0.003  0.042  29.0
#
#       ...  적설(cm) 3시간신적설(cm) 전운량(10분위) 중하층운량(10분위)  시정(10m)  지면온도(°C)  \
# 0     ...     0.0        0.0       0.0           0     2000      17.8
# 1     ...     0.0        0.0       0.0           0     2000      17.4
# 2     ...     0.0        0.0       0.0           0     2000      17.2
# 3     ...     0.0        0.0       0.0           0     2000      17.0
# 4     ...     0.0        0.0       0.0           0     2000      16.5
# ...   ...     ...        ...       ...         ...      ...       ...
# 8754  ...     0.0        0.0       0.0           0     2000      20.6
# 8755  ...     0.0        0.0       0.0           0     2000      19.9
# 8756  ...     0.0        0.0       0.0           0     2000      19.2
# 8757  ...     0.0        0.0       0.0           0     2000      18.6
# 8758  ...     0.0        0.0       0.0           0     2000      18.1
#
#       5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# 0             22.3           22.3           22.7           22.9
# 1             22.1           22.0           22.5           22.9
# 2             21.8           21.8           22.4           22.8
# 3             21.6           21.6           22.2           22.8
# 4             21.3           21.4           22.0           22.7
# ...            ...            ...            ...            ...
# 8754          24.2           23.7           23.0           22.6
# 8755          23.7           23.4           23.1           22.8
# 8756          23.3           23.1           23.0           22.9
# 8757          23.0           22.8           22.9           22.9
# 8758          22.6           22.5           22.8           22.9
#
# [8759 rows x 33 columns]

# %%
# df_21, df_22의 남은 결측치를 처리

df_21
# Out:
#           지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0     서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002  0.039  31.0
# 1     서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002  0.035  27.0
# 2     서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002  0.033  28.0
# 3     서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002  0.030  26.0
# 4     서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003  0.026  26.0
# ...      ...   ...     ...  ...         ...    ...  ...    ...    ...   ...
# 8754  서울 종로구  도시대기  111123  종로구  2021093020  0.003  0.7  0.020  0.036  35.0
# 8755  서울 종로구  도시대기  111123  종로구  2021093021  0.003  0.6  0.016  0.035  34.0
# 8756  서울 종로구  도시대기  111123  종로구  2021093022  0.003  0.6  0.012  0.036  30.0
# 8757  서울 종로구  도시대기  111123  종로구  2021093023  0.003  0.6  0.004  0.042  33.0
# 8758  서울 종로구  도시대기  111123  종로구  2021093024  0.003  0.6  0.003  0.042  29.0
#
#       ...  적설(cm) 3시간신적설(cm) 전운량(10분위) 중하층운량(10분위)  시정(10m)  지면온도(°C)  \
# 0     ...     0.0        0.0       0.0           0     2000      17.8
# 1     ...     0.0        0.0       0.0           0     2000      17.4
# 2     ...     0.0        0.0       0.0           0     2000      17.2
# 3     ...     0.0        0.0       0.0           0     2000      17.0
# 4     ...     0.0        0.0       0.0           0     2000      16.5
# ...   ...     ...        ...       ...         ...      ...       ...
# 8754  ...     0.0        0.0       0.0           0     2000      20.6
# 8755  ...     0.0        0.0       0.0           0     2000      19.9
# 8756  ...     0.0        0.0       0.0           0     2000      19.2
# 8757  ...     0.0        0.0       0.0           0     2000      18.6
# 8758  ...     0.0        0.0       0.0           0     2000      18.1
#
#       5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# 0             22.3           22.3           22.7           22.9
# 1             22.1           22.0           22.5           22.9
# 2             21.8           21.8           22.4           22.8
# 3             21.6           21.6           22.2           22.8
# 4             21.3           21.4           22.0           22.7
# ...            ...            ...            ...            ...
# 8754          24.2           23.7           23.0           22.6
# 8755          23.7           23.4           23.1           22.8
# 8756          23.3           23.1           23.0           22.9
# 8757          23.0           22.8           22.9           22.9
# 8758          22.6           22.5           22.8           22.9
#
# [8759 rows x 33 columns]

# %%
# df_21, df_22의 결측치 재확인
df_21.isnull().sum()
# Out:
# 지역                 0
# 망                  0
# 측정소코드              0
# 측정소명               0
# 측정일시               0
# SO2              112
# CO                80
# O3                97
# NO2               80
# PM10             105
# PM25              97
# 주소                 0
# time               0
# 일시                 0
# 기온(°C)             0
# 강수량(mm)            0
# 풍속(m/s)            2
# 풍향(16방위)           2
# 습도(%)              0
# 증기압(hPa)           0
# 이슬점온도(°C)          0
# 현지기압(hPa)          0
# 해면기압(hPa)          0
# 적설(cm)             0
# 3시간신적설(cm)         0
# 전운량(10분위)          2
# 중하층운량(10분위)        0
# 시정(10m)            0
# 지면온도(°C)           5
# 5cm 지중온도(°C)       5
# 10cm 지중온도(°C)      5
# 20cm 지중온도(°C)      5
# 30cm 지중온도(°C)      5
# dtype: int64

# %%
df_21.fillna(0, inplace=True)
df_22.fillna(0, inplace=True)
df_21.isnull().sum()
# Out:
# 지역               0
# 망                0
# 측정소코드            0
# 측정소명             0
# 측정일시             0
# SO2              0
# CO               0
# O3               0
# NO2              0
# PM10             0
# PM25             0
# 주소               0
# time             0
# 일시               0
# 기온(°C)           0
# 강수량(mm)          0
# 풍속(m/s)          0
# 풍향(16방위)         0
# 습도(%)            0
# 증기압(hPa)         0
# 이슬점온도(°C)        0
# 현지기압(hPa)        0
# 해면기압(hPa)        0
# 적설(cm)           0
# 3시간신적설(cm)       0
# 전운량(10분위)        0
# 중하층운량(10분위)      0
# 시정(10m)          0
# 지면온도(°C)         0
# 5cm 지중온도(°C)     0
# 10cm 지중온도(°C)    0
# 20cm 지중온도(°C)    0
# 30cm 지중온도(°C)    0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-6] 전일 같은 시간 변수 추가</span>**

# %% [markdown]
# * 모델링에 유용한 변수로 전일 같은 시간(24시간 전) 미세먼지 농도 변수를 추가합니다.
# * 시계열 데이터 처리를 위한 shift 연산을 참고하세요.

# %%
# df_21, df_22의 index(time)를 month, day, hour 로 쪼개기 (year는 필요 없음)

df_21['month'] = df_21['time'].dt.month
df_21['day'] = df_21['time'].dt.day
df_21['hour'] = df_21['time'].dt.hour

df_22['month'] = df_22['time'].dt.month
df_22['day'] = df_22['time'].dt.day
df_22['hour'] = df_22['time'].dt.hour

# %%
df_21.set_index(keys='time', inplace=True)
df_22.set_index(keys='time', inplace=True)

# %%
# df_21, df_22에 전일 같은 시간 미세먼지 농도 변수(PM10_lag1) 추가
# 전일 같은 시간은 24시간 전 입니다.
# df_shifted = df_test.shift(-1)

df_21['PM10_lag1'] = df_21['PM10'].shift(-24)
df_22['PM10_lag1'] = df_22['PM10'].shift(-24)
df_21
# Out:
#                          지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3  \
# time
# 2021-10-01 00:00:00  서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002
# 2021-10-01 01:00:00  서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002
# 2021-10-01 02:00:00  서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002
# 2021-10-01 03:00:00  서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002
# 2021-10-01 04:00:00  서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003
# ...                     ...   ...     ...  ...         ...    ...  ...    ...
# 2021-09-30 19:00:00  서울 종로구  도시대기  111123  종로구  2021093020  0.003  0.7  0.020
# 2021-09-30 20:00:00  서울 종로구  도시대기  111123  종로구  2021093021  0.003  0.6  0.016
# 2021-09-30 21:00:00  서울 종로구  도시대기  111123  종로구  2021093022  0.003  0.6  0.012
# 2021-09-30 22:00:00  서울 종로구  도시대기  111123  종로구  2021093023  0.003  0.6  0.004
# 2021-09-30 23:00:00  서울 종로구  도시대기  111123  종로구  2021093024  0.003  0.6  0.003
#
#                        NO2  PM10  ...  지면온도(°C) 5cm 지중온도(°C) 10cm 지중온도(°C)  \
# time                              ...
# 2021-10-01 00:00:00  0.039  31.0  ...      17.8         22.3          22.3
# 2021-10-01 01:00:00  0.035  27.0  ...      17.4         22.1          22.0
# 2021-10-01 02:00:00  0.033  28.0  ...      17.2         21.8          21.8
# 2021-10-01 03:00:00  0.030  26.0  ...      17.0         21.6          21.6
# 2021-10-01 04:00:00  0.026  26.0  ...      16.5         21.3          21.4
# ...                    ...   ...  ...       ...          ...           ...
# 2021-09-30 19:00:00  0.036  35.0  ...      20.6         24.2          23.7
# 2021-09-30 20:00:00  0.035  34.0  ...      19.9         23.7          23.4
# 2021-09-30 21:00:00  0.036  30.0  ...      19.2         23.3          23.1
# 2021-09-30 22:00:00  0.042  33.0  ...      18.6         23.0          22.8
# 2021-09-30 23:00:00  0.042  29.0  ...      18.1         22.6          22.5
#
#                      20cm 지중온도(°C)  30cm 지중온도(°C)  month  day  hour  PM10_1  \
# time
# 2021-10-01 00:00:00           22.7           22.9     10    1     0     NaN
# 2021-10-01 01:00:00           22.5           22.9     10    1     1    31.0
# 2021-10-01 02:00:00           22.4           22.8     10    1     2    27.0
# 2021-10-01 03:00:00           22.2           22.8     10    1     3    28.0
# 2021-10-01 04:00:00           22.0           22.7     10    1     4    26.0
# ...                            ...            ...    ...  ...   ...     ...
# 2021-09-30 19:00:00           23.0           22.6      9   30    19    36.0
# 2021-09-30 20:00:00           23.1           22.8      9   30    20    35.0
# 2021-09-30 21:00:00           23.0           22.9      9   30    21    34.0
# 2021-09-30 22:00:00           22.9           22.9      9   30    22    30.0
# 2021-09-30 23:00:00           22.8           22.9      9   30    23    33.0
#
#                      PM10_lag1
# time
# 2021-10-01 00:00:00       10.0
# 2021-10-01 01:00:00        9.0
# 2021-10-01 02:00:00        9.0
# 2021-10-01 03:00:00       10.0
# 2021-10-01 04:00:00       11.0
# ...                        ...
# 2021-09-30 19:00:00        NaN
# 2021-09-30 20:00:00        NaN
# 2021-09-30 21:00:00        NaN
# 2021-09-30 22:00:00        NaN
# 2021-09-30 23:00:00        NaN
#
# [8759 rows x 37 columns]

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-7] t+1 시점의 미세먼지 농도 데이터 생성</span>**

# %% [markdown]
# * t+1 시점은 1시간 후 입니다.
# * t+1 시점의 미세먼지 농도 변수를 생성하세요.
# * t+1 시점의 미세먼지 농도는 머신러닝 모델을 통해 예측하려는 y값(target) 입니다.

# %%
# df_21, df_22에 t+1 시점 변수(PM10_1) 추가
df_21['PM10_1'] = df_21['PM10'].shift(1)
df_22['PM10_1'] = df_22['PM10'].shift(1)

# %%
df_21
# Out:
#                          지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3  \
# time
# 2021-10-01 00:00:00  서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002
# 2021-10-01 01:00:00  서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002
# 2021-10-01 02:00:00  서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002
# 2021-10-01 03:00:00  서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002
# 2021-10-01 04:00:00  서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003
# ...                     ...   ...     ...  ...         ...    ...  ...    ...
# 2021-09-30 19:00:00  서울 종로구  도시대기  111123  종로구  2021093020  0.003  0.7  0.020
# 2021-09-30 20:00:00  서울 종로구  도시대기  111123  종로구  2021093021  0.003  0.6  0.016
# 2021-09-30 21:00:00  서울 종로구  도시대기  111123  종로구  2021093022  0.003  0.6  0.012
# 2021-09-30 22:00:00  서울 종로구  도시대기  111123  종로구  2021093023  0.003  0.6  0.004
# 2021-09-30 23:00:00  서울 종로구  도시대기  111123  종로구  2021093024  0.003  0.6  0.003
#
#                        NO2  PM10  ...  지면온도(°C) 5cm 지중온도(°C) 10cm 지중온도(°C)  \
# time                              ...
# 2021-10-01 00:00:00  0.039  31.0  ...      17.8         22.3          22.3
# 2021-10-01 01:00:00  0.035  27.0  ...      17.4         22.1          22.0
# 2021-10-01 02:00:00  0.033  28.0  ...      17.2         21.8          21.8
# 2021-10-01 03:00:00  0.030  26.0  ...      17.0         21.6          21.6
# 2021-10-01 04:00:00  0.026  26.0  ...      16.5         21.3          21.4
# ...                    ...   ...  ...       ...          ...           ...
# 2021-09-30 19:00:00  0.036  35.0  ...      20.6         24.2          23.7
# 2021-09-30 20:00:00  0.035  34.0  ...      19.9         23.7          23.4
# 2021-09-30 21:00:00  0.036  30.0  ...      19.2         23.3          23.1
# 2021-09-30 22:00:00  0.042  33.0  ...      18.6         23.0          22.8
# 2021-09-30 23:00:00  0.042  29.0  ...      18.1         22.6          22.5
#
#                      20cm 지중온도(°C)  30cm 지중온도(°C)  month  day  hour  PM10_1  \
# time
# 2021-10-01 00:00:00           22.7           22.9     10    1     0     NaN
# 2021-10-01 01:00:00           22.5           22.9     10    1     1    31.0
# 2021-10-01 02:00:00           22.4           22.8     10    1     2    27.0
# 2021-10-01 03:00:00           22.2           22.8     10    1     3    28.0
# 2021-10-01 04:00:00           22.0           22.7     10    1     4    26.0
# ...                            ...            ...    ...  ...   ...     ...
# 2021-09-30 19:00:00           23.0           22.6      9   30    19    36.0
# 2021-09-30 20:00:00           23.1           22.8      9   30    20    35.0
# 2021-09-30 21:00:00           23.0           22.9      9   30    21    34.0
# 2021-09-30 22:00:00           22.9           22.9      9   30    22    30.0
# 2021-09-30 23:00:00           22.8           22.9      9   30    23    33.0
#
#                      PM10_lag1
# time
# 2021-10-01 00:00:00       10.0
# 2021-10-01 01:00:00        9.0
# 2021-10-01 02:00:00        9.0
# 2021-10-01 03:00:00       10.0
# 2021-10-01 04:00:00       11.0
# ...                        ...
# 2021-09-30 19:00:00        NaN
# 2021-09-30 20:00:00        NaN
# 2021-09-30 21:00:00        NaN
# 2021-09-30 22:00:00        NaN
# 2021-09-30 23:00:00        NaN
#
# [8759 rows x 37 columns]

# %%
# 결측치가 있다면 처리
df_21.fillna(0, inplace=True)
df_22.fillna(0, inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# #### **<span style="color:blue">[2-8] train, test 데이터 분리</span>**

# %% [markdown]
# * 21년도 데이터(df_21)를 train 데이터로 저장하세요. y 값을 제외하고 train_x로 저장한 후 y 값은 train_y로 저장하세요.
# * 22년도 데이터(df_22)를 test 데이터로 저장하세요. y 값을 제외하고 test_x로 저장한 후 y 값은 test_y로 저장하세요.
# * 각각의 데이터프레임을 csv 파일로 저장하세요. (train_x.csv / train_y.csv / test_x.csv / test_y.csv)
# * y값은 'PM10_1' 즉, t+1 시점의 미세먼지 농도입니다.

# %%
# 아래에 필요한 코드를 작성하고 결과를 확인합니다.

df_21['PM10_1'].to_csv('train_y.csv', index=True)
df_22['PM10_1'].to_csv('test_y.csv', index=True)

df_21.drop('PM10_1', axis=1, inplace=True)
df_21.to_csv('train_x.csv', index=True)
df_22.drop('PM10_1', axis=1, inplace=True)
df_22.to_csv('test_x.csv', index=True)

# %%
# 각각의 데이터프레임을 csv 파일로 저장 (train_x.csv / train_y.csv / test_x.csv / test_y.csv)
